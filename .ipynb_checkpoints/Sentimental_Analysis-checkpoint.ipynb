# %%
import pandas as pd

# %%
reading_json = pd.read_json("Sample Data.txt" , lines = True)

# %%
reading_json.to_csv("Sentimental_data.csv" , index = None)

# %%
df = pd.read_csv("Sentimental_data.csv")

# %%
df.isna().sum()
# Out:
# _type                  0
# url                    0
# date                   0
# content                0
# renderedContent        0
# id                     0
# user                   0
# replyCount             0
# retweetCount           0
# likeCount              0
# quoteCount             0
# conversationId         0
# lang                   0
# source                 0
# sourceUrl              0
# sourceLabel            0
# outlinks            3588
# tcooutlinks         3588
# media               2224
# retweetedTweet      5642
# quotedTweet         5424
# inReplyToTweetId    5373
# inReplyToUser       5373
# mentionedUsers      4630
# coordinates         5020
# place               5020
# hashtags               0
# cashtags            5627
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 51509

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Removing stopwords

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
STOPWORDS = set(stopwords.words('english'))
def cleaning_stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])
df['content'] = df['content'].apply(lambda text: cleaning_stopwords(text))
df['content'].head()
# Out:
# 0    ⭐ THANK YOU ⭐ Our popular #Sunday night pub qu...
# 1    Ahhh big stars #gayweho #redressparty #mickysw...
# 2    Without God week would SINDAY MOURNDAY TEARSDA...
# 3    #awesome #Attitude #Motivation #commitment #Su...
# 4    @BadalonaCC #Sunday training @omaree02 @Cricke...
# Name: content, dtype: object

# %%
df['content']=df['content'].str.lower()
df['content'].head()
# Out:
# 0    ⭐ thank you ⭐ our popular #sunday night pub qu...
# 1    ahhh big stars #gayweho #redressparty #mickysw...
# 2    without god week would sinday mournday tearsda...
# 3    #awesome #attitude #motivation #commitment #su...
# 4    @badalonacc #sunday training @omaree02 @cricke...
# Name: content, dtype: object

# %%
import string
english_punctuations = string.punctuation
punctuations_list = english_punctuations
def cleaning_punctuations(text):
    translator = str.maketrans('', '', punctuations_list)
    return text.translate(translator)
df['content']= df['content'].apply(lambda x: cleaning_punctuations(x))
df['content'].head()
# Out:
# 0    ⭐ thank you ⭐ our popular sunday night pub qui...
# 1    ahhh big stars gayweho redressparty mickysweho...
# 2    without god week would sinday mournday tearsda...
# 3    awesome attitude motivation commitment sunday ...
# 4    badalonacc sunday training omaree02 cricketpun...
# Name: content, dtype: object

# %%
import re
def cleaning_repeating_char(text):
    return re.sub(r'(.)1+', r'1', text)
df['content'] = df['content'].apply(lambda x: cleaning_repeating_char(x))
df['content'].head()
# Out:
# 0    ⭐ thank you ⭐ our popular sunday night pub qui...
# 1    ahhh big stars gayweho redressparty mickysweho...
# 2    without god week would sinday mournday tearsda...
# 3    awesome attitude motivation commitment sunday ...
# 4    badalonacc sunday training omaree02 cricketpun...
# Name: content, dtype: object

# %%
def cleaning_URLs(data):
    return re.sub('((www.[^s]+)|(https?://[^s]+))',' ',data)
df['content'] = df['content'].apply(lambda x: cleaning_URLs(x))
df['content'].head()
# Out:
# 0    ⭐ thank you ⭐ our popular sunday night pub qui...
# 1    ahhh big stars gayweho redressparty mickysweho...
# 2    without god week would sinday mournday tearsda...
# 3    awesome attitude motivation commitment sunday ...
# 4    badalonacc sunday training omaree02 cricketpun...
# Name: content, dtype: object

# %%
def cleaning_numbers(data):
    return re.sub('[0-9]+', ' ', data)
df['content'] = df['content'].apply(lambda x: cleaning_numbers(x))
df['content'].head()
# Out:
# 0    ⭐ thank you ⭐ our popular sunday night pub qui...
# 1    ahhh big stars gayweho redressparty mickysweho...
# 2    without god week would sinday mournday tearsda...
# 3    awesome attitude motivation commitment sunday ...
# 4    badalonacc sunday training omaree  cricketpunt...
# Name: content, dtype: object

# %%
def transform_text(text):
    return ' '.join([word for word in text.split() if len(word) > 2])
df['content'] = df['content'].apply(lambda x: transform_text(x))
df['content']
# Out:
# 0       thank you our popular sunday night pub quizzes...
# 1       ahhh big stars gayweho redressparty mickysweho...
# 2       without god week would sinday mournday tearsda...
# 3       awesome attitude motivation commitment sunday ...
# 4       badalonacc sunday training omaree cricketpuntc...
#                               ...
# 5637    open space heart within being like cup🤲i allow...
# 5638    linda caminata por salud placer openair health...
# 5639    realkarlbeattie yfielding marymbeattie myheroe...
# 5640    white tea rose bushes front yard these durable...
# 5641    last boat ride summer store boat winter always...
# Name: content, Length: 5642, dtype: object

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

# Reads 'Youtube04-Eminem.csv' file
df = pd.read_csv(r"Sentimental_data.csv")

comment_words = ''
stopwords = set(STOPWORDS)

# iterate through the csv file
for val in df.content:
	
	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()
	
	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()
	
	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image					
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
def transform_text(text):
    return ' '.join([word for word in text.split() if len(word) > 2])
df['content'] = df['content'].apply(lambda x: transform_text(x))
df['content']
from textblob import TextBlob

# %%
def polarity_ofthe_sentiment(text):
    return TextBlob(text).sentiment.polarity

def subjectivity(text):
    res = TextBlob(text)
    return res.sentiment.subjectivity

df['Polarity'] = df['content'].apply(polarity_ofthe_sentiment)
df["subjectivity"] = df['content'].apply(subjectivity)
df
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 5637  snscrape.modules.twitter.Tweet
# 5638  snscrape.modules.twitter.Tweet
# 5639  snscrape.modules.twitter.Tweet
# 5640  snscrape.modules.twitter.Tweet
# 5641  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/theworkingboat/status/1460...
# 1     https://twitter.com/WeHoLove/status/1460523193...
# 2     https://twitter.com/bdsrated/status/1460518587...
# 3     https://twitter.com/maggietranquila/status/146...
# 4     https://twitter.com/BadalonaCC/status/14605071...
# ...                                                 ...
# 5637  https://twitter.com/BruddaZen/status/145748830...
# 5638  https://twitter.com/YarnsWool/status/145748824...
# 5639  https://twitter.com/BringonFoxFever/status/145...
# 5640  https://twitter.com/Skye3411/status/1457487967...
# 5641  https://twitter.com/mileslong4real/status/1457...
#
#                            date  \
# 0     2021-11-16 09:54:20+00:00
# 1     2021-11-16 08:20:39+00:00
# 2     2021-11-16 08:02:21+00:00
# 3     2021-11-16 07:34:44+00:00
# 4     2021-11-16 07:16:46+00:00
# ...                         ...
# 5637  2021-11-07 23:21:04+00:00
# 5638  2021-11-07 23:20:51+00:00
# 5639  2021-11-07 23:20:26+00:00
# 5640  2021-11-07 23:19:44+00:00
# 5641  2021-11-07 23:18:48+00:00
#
#                                                 content  \
# 0     THANK YOU Our popular #Sunday night pub quizze...
# 1     Ahhh big stars #gayweho #redressparty #mickysw...
# 2     Without God our week would SINDAY MOURNDAY TEA...
# 3     #awesome #Attitude #Motivation #commitment #Su...
# 4     @BadalonaCC #Sunday training with @omaree02 @C...
# ...                                                 ...
# 5637  can open space heart, within being, like cup.🤲...
# 5638  Linda caminata km) por salud placer. #openair ...
# 5639  @realkarlbeattie @Yfielding @marymbeattie #MyH...
# 5640  have about White Tea Rose bushes front yard. T...
# 5641  Last Boat ride the summer before store the boa...
#
#                                         renderedContent                   id  \
# 0     ⭐ THANK YOU ⭐\n\nOur popular #Sunday night pub...  1460546769096425476
# 1     Ahhh big stars in #gayweho #redressparty #mick...  1460523193395933188
# 2     Without God\nour week would be\nSINDAY\nMOURND...  1460518587639025673
# 3     #awesome #Attitude #Motivation #commitment #Su...  1460511638856114185
# 4     @BadalonaCC #Sunday training with @omaree02\n\...  1460507115982925826
# ...                                                 ...                  ...
# 5637  I can open up space in my heart, within my bei...  1457488300273405952
# 5638  Linda caminata (8 km) por salud y placer. #ope...  1457488248528277504
# 5639  @realkarlbeattie @Yfielding @marymbeattie #MyH...  1457488143544946692
# 5640  I have about 20 White Tea Rose bushes in my fr...  1457487967669211145
# 5641  Last Boat ride of the summer before we store t...  1457487730200305668
#
#                                                    user  replyCount  \
# 0     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                 ...         ...
# 5637  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5638  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5639  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 5640  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5641  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#       retweetCount  likeCount  ...  quotedTweet  inReplyToTweetId  \
# 0                0          0  ...          NaN               NaN
# 1                0          3  ...          NaN               NaN
# 2                0          0  ...          NaN               NaN
# 3                0          0  ...          NaN               NaN
# 4                2          4  ...          NaN               NaN
# ...            ...        ...  ...          ...               ...
# 5637             0          0  ...          NaN               NaN
# 5638             1          2  ...          NaN               NaN
# 5639             0          3  ...          NaN               NaN
# 5640             0          0  ...          NaN               NaN
# 5641             2          9  ...          NaN               NaN
#
#      inReplyToUser                                     mentionedUsers  \
# 0              NaN  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 1              NaN                                                NaN
# 2              NaN  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3              NaN                                                NaN
# 4              NaN  [{'_type': 'snscrape.modules.twitter.User', 'u...
# ...            ...                                                ...
# 5637           NaN                                                NaN
# 5638           NaN                                                NaN
# 5639           NaN  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 5640           NaN                                                NaN
# 5641           NaN  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#                                             coordinates  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5637                                                NaN
# 5638  {'_type': 'snscrape.modules.twitter.Coordinate...
# 5639                                                NaN
# 5640                                                NaN
# 5641                                                NaN
#
#                                                   place  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5637                                                NaN
# 5638  {'_type': 'snscrape.modules.twitter.Place', 'f...
# 5639                                                NaN
# 5640                                                NaN
# 5641                                                NaN
#
#                                                hashtags cashtags  Polarity  \
# 0              ['Sunday', 'TheWorkingBoat', 'Falmouth']      NaN  0.385714
# 1     ['gayweho', 'redressparty', 'mickysweho', 'Sun...      NaN  0.000000
# 2     ['CHURCH', 'SUNDAY', 'BDMS', 'SOMEWHEREINCAVIT...      NaN -0.375000
# 3     ['awesome', 'Attitude', 'Motivation', 'commitm...      NaN  1.000000
# 4                                            ['Sunday']      NaN  0.000000
# ...                                                 ...      ...       ...
# 5637  ['sundayvibes', 'SundayFunday', 'SundayThought...      NaN  0.300000
# 5638  ['openair', 'healthylife', 'walk', 'Sunday', '...      NaN  0.000000
# 5639           ['MyHeroes', 'Sunday', 'animaloftheday']      NaN  0.800000
# 5640          ['Flowers', 'GardeningTwitter', 'Sunday']      NaN  0.366667
# 5641     ['sundayfunday', 'sunday', 'livingmybestlife']      NaN  0.400000
#
#       subjectivity
# 0         0.464286
# 1         0.100000
# 2         0.625000
# 3         1.000000
# 4         0.000000
# ...            ...
# 5637      0.666667
# 5638      0.000000
# 5639      1.000000
# 5640      0.483333
# 5641      0.622222
#
# [5642 rows x 30 columns]

# %%
import enchant
dictionary = enchant.Dict("en_US")
def perecentage_of_complex_words(text):
    words = text.split(" ")
    en_count = 0.0
    for word in words:
          if dictionary.check(word.strip()):
            en_count += 1
    percent = en_count/len(words) if len(words) != 0 else 0
    return percent*100
df["PERCENTAGE OF COMPLEX WORDS"] = df['content'].apply(perecentage_of_complex_words)

# %%
import re
def personal_pronoun(text):
    pronounRegex = re.compile(r'\b(I|you|he|she|it|we|they|me|him|her|us|them|(?-i:us))\b',re.I)
    pronouns = pronounRegex.findall(text)
    return pronouns
df['PERSONAL PRONOUNS'] = df['content'].apply(personal_pronoun)

# %%
def Analysizing(score):
    if score<0:
        return 'negative'
    elif score==0:
        return 'neutral'
    else:
        return 'positive'
    
df['analysis']=df['Polarity'].apply(Analysizing)
df
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 5637  snscrape.modules.twitter.Tweet
# 5638  snscrape.modules.twitter.Tweet
# 5639  snscrape.modules.twitter.Tweet
# 5640  snscrape.modules.twitter.Tweet
# 5641  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/theworkingboat/status/1460...
# 1     https://twitter.com/WeHoLove/status/1460523193...
# 2     https://twitter.com/bdsrated/status/1460518587...
# 3     https://twitter.com/maggietranquila/status/146...
# 4     https://twitter.com/BadalonaCC/status/14605071...
# ...                                                 ...
# 5637  https://twitter.com/BruddaZen/status/145748830...
# 5638  https://twitter.com/YarnsWool/status/145748824...
# 5639  https://twitter.com/BringonFoxFever/status/145...
# 5640  https://twitter.com/Skye3411/status/1457487967...
# 5641  https://twitter.com/mileslong4real/status/1457...
#
#                            date  \
# 0     2021-11-16 09:54:20+00:00
# 1     2021-11-16 08:20:39+00:00
# 2     2021-11-16 08:02:21+00:00
# 3     2021-11-16 07:34:44+00:00
# 4     2021-11-16 07:16:46+00:00
# ...                         ...
# 5637  2021-11-07 23:21:04+00:00
# 5638  2021-11-07 23:20:51+00:00
# 5639  2021-11-07 23:20:26+00:00
# 5640  2021-11-07 23:19:44+00:00
# 5641  2021-11-07 23:18:48+00:00
#
#                                                 content  \
# 0     THANK YOU Our popular #Sunday night pub quizze...
# 1     Ahhh big stars #gayweho #redressparty #mickysw...
# 2     Without God our week would SINDAY MOURNDAY TEA...
# 3     #awesome #Attitude #Motivation #commitment #Su...
# 4     @BadalonaCC #Sunday training with @omaree02 @C...
# ...                                                 ...
# 5637  can open space heart, within being, like cup.🤲...
# 5638  Linda caminata km) por salud placer. #openair ...
# 5639  @realkarlbeattie @Yfielding @marymbeattie #MyH...
# 5640  have about White Tea Rose bushes front yard. T...
# 5641  Last Boat ride the summer before store the boa...
#
#                                         renderedContent                   id  \
# 0     ⭐ THANK YOU ⭐\n\nOur popular #Sunday night pub...  1460546769096425476
# 1     Ahhh big stars in #gayweho #redressparty #mick...  1460523193395933188
# 2     Without God\nour week would be\nSINDAY\nMOURND...  1460518587639025673
# 3     #awesome #Attitude #Motivation #commitment #Su...  1460511638856114185
# 4     @BadalonaCC #Sunday training with @omaree02\n\...  1460507115982925826
# ...                                                 ...                  ...
# 5637  I can open up space in my heart, within my bei...  1457488300273405952
# 5638  Linda caminata (8 km) por salud y placer. #ope...  1457488248528277504
# 5639  @realkarlbeattie @Yfielding @marymbeattie #MyH...  1457488143544946692
# 5640  I have about 20 White Tea Rose bushes in my fr...  1457487967669211145
# 5641  Last Boat ride of the summer before we store t...  1457487730200305668
#
#                                                    user  replyCount  \
# 0     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                 ...         ...
# 5637  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5638  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5639  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 5640  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5641  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#       retweetCount  likeCount  ...  \
# 0                0          0  ...
# 1                0          3  ...
# 2                0          0  ...
# 3                0          0  ...
# 4                2          4  ...
# ...            ...        ...  ...
# 5637             0          0  ...
# 5638             1          2  ...
# 5639             0          3  ...
# 5640             0          0  ...
# 5641             2          9  ...
#
#                                          mentionedUsers  \
# 0     [{'_type': 'snscrape.modules.twitter.User', 'u...
# 1                                                   NaN
# 2     [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3                                                   NaN
# 4     [{'_type': 'snscrape.modules.twitter.User', 'u...
# ...                                                 ...
# 5637                                                NaN
# 5638                                                NaN
# 5639  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 5640                                                NaN
# 5641  [{'_type': 'snscrape.modules.twitter.User', 'u...
#
#                                             coordinates  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5637                                                NaN
# 5638  {'_type': 'snscrape.modules.twitter.Coordinate...
# 5639                                                NaN
# 5640                                                NaN
# 5641                                                NaN
#
#                                                   place  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5637                                                NaN
# 5638  {'_type': 'snscrape.modules.twitter.Place', 'f...
# 5639                                                NaN
# 5640                                                NaN
# 5641                                                NaN
#
#                                                hashtags cashtags  Polarity  \
# 0              ['Sunday', 'TheWorkingBoat', 'Falmouth']      NaN  0.385714
# 1     ['gayweho', 'redressparty', 'mickysweho', 'Sun...      NaN  0.000000
# 2     ['CHURCH', 'SUNDAY', 'BDMS', 'SOMEWHEREINCAVIT...      NaN -0.375000
# 3     ['awesome', 'Attitude', 'Motivation', 'commitm...      NaN  1.000000
# 4                                            ['Sunday']      NaN  0.000000
# ...                                                 ...      ...       ...
# 5637  ['sundayvibes', 'SundayFunday', 'SundayThought...      NaN  0.300000
# 5638  ['openair', 'healthylife', 'walk', 'Sunday', '...      NaN  0.000000
# 5639           ['MyHeroes', 'Sunday', 'animaloftheday']      NaN  0.800000
# 5640          ['Flowers', 'GardeningTwitter', 'Sunday']      NaN  0.366667
# 5641     ['sundayfunday', 'sunday', 'livingmybestlife']      NaN  0.400000
#
#      subjectivity PERCENTAGE OF COMPLEX WORDS PERSONAL PRONOUNS  analysis
# 0        0.464286                   76.923077        [YOU, you]  positive
# 1        0.100000                   16.666667                []   neutral
# 2        0.625000                   45.454545                []  negative
# 3        1.000000                    9.090909                []  positive
# 4        0.000000                    9.090909                []   neutral
# ...           ...                         ...               ...       ...
# 5637     0.666667                   70.967742               [I]  positive
# 5638     0.000000                   15.384615                []   neutral
# 5639     1.000000                   12.500000                []  positive
# 5640     0.483333                   76.000000                []  positive
# 5641     0.622222                   74.285714                []  positive
#
# [5642 rows x 33 columns]

# %%
df.drop(['hashtags' , 'place' , 'cashtags' , 'coordinates' , 'retweetedTweet' , 'quotedTweet' , 'inReplyToTweetId','inReplyToUser' , 'mentionedUsers' , 'media' , 'tcooutlinks','outlinks','sourceUrl'] , axis = 1)
# Out:
#                                _type  \
# 0     snscrape.modules.twitter.Tweet
# 1     snscrape.modules.twitter.Tweet
# 2     snscrape.modules.twitter.Tweet
# 3     snscrape.modules.twitter.Tweet
# 4     snscrape.modules.twitter.Tweet
# ...                              ...
# 5637  snscrape.modules.twitter.Tweet
# 5638  snscrape.modules.twitter.Tweet
# 5639  snscrape.modules.twitter.Tweet
# 5640  snscrape.modules.twitter.Tweet
# 5641  snscrape.modules.twitter.Tweet
#
#                                                     url  \
# 0     https://twitter.com/theworkingboat/status/1460...
# 1     https://twitter.com/WeHoLove/status/1460523193...
# 2     https://twitter.com/bdsrated/status/1460518587...
# 3     https://twitter.com/maggietranquila/status/146...
# 4     https://twitter.com/BadalonaCC/status/14605071...
# ...                                                 ...
# 5637  https://twitter.com/BruddaZen/status/145748830...
# 5638  https://twitter.com/YarnsWool/status/145748824...
# 5639  https://twitter.com/BringonFoxFever/status/145...
# 5640  https://twitter.com/Skye3411/status/1457487967...
# 5641  https://twitter.com/mileslong4real/status/1457...
#
#                            date  \
# 0     2021-11-16 09:54:20+00:00
# 1     2021-11-16 08:20:39+00:00
# 2     2021-11-16 08:02:21+00:00
# 3     2021-11-16 07:34:44+00:00
# 4     2021-11-16 07:16:46+00:00
# ...                         ...
# 5637  2021-11-07 23:21:04+00:00
# 5638  2021-11-07 23:20:51+00:00
# 5639  2021-11-07 23:20:26+00:00
# 5640  2021-11-07 23:19:44+00:00
# 5641  2021-11-07 23:18:48+00:00
#
#                                                 content  \
# 0     THANK YOU Our popular #Sunday night pub quizze...
# 1     Ahhh big stars #gayweho #redressparty #mickysw...
# 2     Without God our week would SINDAY MOURNDAY TEA...
# 3     #awesome #Attitude #Motivation #commitment #Su...
# 4     @BadalonaCC #Sunday training with @omaree02 @C...
# ...                                                 ...
# 5637  can open space heart, within being, like cup.🤲...
# 5638  Linda caminata km) por salud placer. #openair ...
# 5639  @realkarlbeattie @Yfielding @marymbeattie #MyH...
# 5640  have about White Tea Rose bushes front yard. T...
# 5641  Last Boat ride the summer before store the boa...
#
#                                         renderedContent                   id  \
# 0     ⭐ THANK YOU ⭐\n\nOur popular #Sunday night pub...  1460546769096425476
# 1     Ahhh big stars in #gayweho #redressparty #mick...  1460523193395933188
# 2     Without God\nour week would be\nSINDAY\nMOURND...  1460518587639025673
# 3     #awesome #Attitude #Motivation #commitment #Su...  1460511638856114185
# 4     @BadalonaCC #Sunday training with @omaree02\n\...  1460507115982925826
# ...                                                 ...                  ...
# 5637  I can open up space in my heart, within my bei...  1457488300273405952
# 5638  Linda caminata (8 km) por salud y placer. #ope...  1457488248528277504
# 5639  @realkarlbeattie @Yfielding @marymbeattie #MyH...  1457488143544946692
# 5640  I have about 20 White Tea Rose bushes in my fr...  1457487967669211145
# 5641  Last Boat ride of the summer before we store t...  1457487730200305668
#
#                                                    user  replyCount  \
# 0     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 4     {'_type': 'snscrape.modules.twitter.User', 'us...           0
# ...                                                 ...         ...
# 5637  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5638  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5639  {'_type': 'snscrape.modules.twitter.User', 'us...           2
# 5640  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 5641  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#       retweetCount  likeCount  quoteCount       conversationId lang  \
# 0                0          0           0  1460546769096425476   en
# 1                0          3           0  1460523193395933188   en
# 2                0          0           0  1460518587639025673   en
# 3                0          0           0  1460511638856114185  und
# 4                2          4           0  1460507115982925826   en
# ...            ...        ...         ...                  ...  ...
# 5637             0          0           0  1457488300273405952   en
# 5638             1          2           0  1457488248528277504   es
# 5639             0          3           0  1457488143544946692   en
# 5640             0          0           0  1457487967669211145   en
# 5641             2          9           0  1457487730200305668   en
#
#                                                  source  \
# 0     <a href="https://mobile.twitter.com" rel="nofo...
# 1     <a href="http://Gay-Los-Angeles.com" rel="nofo...
# 2     <a href="http://twitter.com/download/android" ...
# 3     <a href="http://instagram.com" rel="nofollow">...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 5637  <a href="https://mobile.twitter.com" rel="nofo...
# 5638  <a href="http://twitter.com/download/iphone" r...
# 5639  <a href="https://mobile.twitter.com" rel="nofo...
# 5640  <a href="http://twitter.com/download/iphone" r...
# 5641  <a href="http://twitter.com/download/android" ...
#
#                       sourceLabel  Polarity  subjectivity  \
# 0                 Twitter Web App  0.385714      0.464286
# 1     http://GayWestHollywood.com  0.000000      0.100000
# 2             Twitter for Android -0.375000      0.625000
# 3                       Instagram  1.000000      1.000000
# 4              Twitter for iPhone  0.000000      0.000000
# ...                           ...       ...           ...
# 5637              Twitter Web App  0.300000      0.666667
# 5638           Twitter for iPhone  0.000000      0.000000
# 5639              Twitter Web App  0.800000      1.000000
# 5640           Twitter for iPhone  0.366667      0.483333
# 5641          Twitter for Android  0.400000      0.622222
#
#       PERCENTAGE OF COMPLEX WORDS PERSONAL PRONOUNS  analysis
# 0                       76.923077        [YOU, you]  positive
# 1                       16.666667                []   neutral
# 2                       45.454545                []  negative
# 3                        9.090909                []  positive
# 4                        9.090909                []   neutral
# ...                           ...               ...       ...
# 5637                    70.967742               [I]  positive
# 5638                    15.384615                []   neutral
# 5639                    12.500000                []  positive
# 5640                    76.000000                []  positive
# 5641                    74.285714                []  positive
#
# [5642 rows x 20 columns]

# %%
import seaborn as sns
df['analysis'] = df['analysis'].map({'positive':1 , 'negative':-1 , 'neutral':0} , na_action=None)
sns.countplot(data = df , x = 'analysis' , order = df['analysis'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='analysis', ylabel='count'>

# %%
def remove_tags(string):
    removelist = ""
    result = re.sub('','',string)          #remove HTML tags
    result = re.sub('https://.*','',result)   #remove URLs
    result = re.sub(r'[^w'+removelist+']', ' ',result)    #remove non-alphanumeric characters 
    result = result.lower()
    return result
df['content']=df['content'].apply(lambda cw : remove_tags(cw)) 
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
df['content'] = df['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
w_tokenizer = nltk.tokenize.WhitespaceTokenizer()
lemmatizer = nltk.stem.WordNetLemmatizer()
def lemmatize_text(text):
    st = ""
    for w in w_tokenizer.tokenize(text):
        st = st + lemmatizer.lemmatize(w) + " "
    return st
df['content'] = df.content.apply(lemmatize_text)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from sklearn.preprocessing import LabelEncoder
reviews = df['content'].values
labels = df['analysis'].values
encoder = LabelEncoder()
encoded_labels = encoder.fit_transform(labels)

# %%
from sklearn.model_selection import train_test_split
train_sentences, test_sentences, train_labels, test_labels = train_test_split(reviews, encoded_labels, stratify = encoded_labels)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from collections import defaultdict
vec = CountVectorizer(max_features = 3000)
X = vec.fit_transform(train_sentences)
vocab = vec.get_feature_names()
X = X.toarray()
word_counts = {}
for l in range(len(X)):
    word_counts[l] = defaultdict(lambda: 0)
for i in range(X.shape[0]):
    l = train_labels[i]
    for j in range(len(vocab)):
        word_counts[l][vocab[j]] += X[i][j]
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
def laplace_smoothing(n_label_items, vocab, word_counts, word, text_label):
    a = word_counts[text_label][word] + 1
    b = n_label_items[text_label] + len(vocab)
    return math.log(a/b)

# %%
def group_by_label(x, y, labels):
    data = {}
    for l in labels:
        data[l] = x[np.where(y == l)]
    return data

# %%
def fit(x, y, labels):
    n_label_items = {}
    log_label_priors = {}
    n = len(x)
    grouped_data = group_by_label(x, y, labels)
    for l, data in grouped_data.items():
        n_label_items[l] = len(data)
        log_label_priors[l] = math.log(n_label_items[l] / n)
    return n_label_items, log_label_priors

# %%
def predict(n_label_items, vocab, word_counts, log_label_priors, labels, x):
    result = []
    for text in x:
        label_scores = {l: log_label_priors[l] for l in labels}
        words = set(w_tokenizer.tokenize(text))
        for word in words:
            if word not in vocab: continue
            for l in labels:
                log_w_given_l = laplace_smoothing(n_label_items, vocab, word_counts, word, l)
                label_scores[l] += log_w_given_l
        result.append(max(label_scores, key=label_scores.get))
    return result

# %%
import numpy as np
import math
from sklearn.metrics import accuracy_score
labels = [0,1]
n_label_items, log_label_priors = fit(train_sentences,train_labels,labels)
pred = predict(n_label_items, vocab, word_counts, log_label_priors, labels, test_sentences)
print("Accuracy of prediction on test set : ", accuracy_score(test_labels,pred))
# Out:
# Accuracy of prediction on test set :  0.47058823529411764

# %%
from sklearn.metrics import classification_report
print(classification_report(test_labels,pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [33], line 1
# ----> 1 print(classification_report(test_labels,pred))
#
# NameError: name 'classification_report' is not defined
